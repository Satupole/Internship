# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel('customer retention.xlsx')
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#shape of the dataset
data.shape
# Out:
# (269, 71)

# %%
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#checking for null values and object types in dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# No null values seen in dataset

# %%
#describing the dataset
data.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %% [markdown]
# Observation:
# All the columns are categorical in nature.

# %%
#Checking for duplicate values
data.duplicated().sum()
# Out:
# 166

# %%
#removing duplicates
data.drop_duplicates(inplace=True)

# %%
#size of dataset after removing duplicates
data.shape
# Out:
# (103, 71)

# %%
print(data['1Gender of respondent'].value_counts())
sns.countplot(data['1Gender of respondent'])
plt.show()
# Out:
# Female    66
# Male      37
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# Observation: There are  66 females and 37 males who responded to this survey.

# %%
print(data['2 How old are you? '].value_counts())
plt.figure(figsize=(10,5))
sns.countplot(data['2 How old are you? '])
plt.xlabel('Age in years')
plt.show()
# Out:
# 21-30 years           32
# 31-40 years           30
# 41-50 yaers           29
# Less than 20 years     6
# 51 years and above     6
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# Observation:
# - Most shoppers/responders are within age limit of 31-50 years old.Younger people(age<20) and older people(age>51) are less prone to buying items online.

# %%
print(data['3 Which city do you shop online from?'].value_counts())
plt.figure(figsize=(10,5))
sns.countplot(data['3 Which city do you shop online from?'],hue=data['1Gender of respondent'])
plt.xlabel('City')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Delhi            22
# Greater Noida    17
# Bangalore        17
# Noida            17
# Karnal           11
# Merrut            5
# Ghaziabad         5
# Solan             4
# Gurgaon           3
# Moradabad         1
# Bulandshahr       1
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# Observation:
# - Most shoppers/responders are from delhi while lesser in Bulandshahr.
# - Most shoppers are female compared to mail except in Delhi and Noida.

# %%
print(data['5 Since How Long You are Shopping Online ?'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['5 Since How Long You are Shopping Online ?'])
plt.xlabel('Online shopping time in years')
plt.show()
# Out:
# Above 4 years       39
# 2-3 years           23
# Less than 1 year    18
# 3-4 years           16
# 1-2 years            7
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# observation:
# - most of the shoppers are shopping online for more than 4 years while very less people are new shoppers i.e since past 1-2 years.

# %%
print(data['6 How many times you have made an online purchase in the past 1 year?'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['6 How many times you have made an online purchase in the past 1 year?'])
plt.xlabel('Past 1 year online purchases ')
plt.show()
# Out:
# Less than 10 times    39
# 31-40 times           24
# 41 times and above    22
# 11-20 times           12
# 21-30 times            4
# 42 times and above     2
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# Observations:
# - More number of people are non- frequent shoppers i.e. they have shopped <10 times in past 1 year.
# - Only 2 people have shopped online >42 times.

# %%
print(data['7 How do you access the internet while shopping on-line?'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['7 How do you access the internet while shopping on-line?'])
plt.xlabel('Access of internet')
plt.show()
# Out:
# Mobile internet    70
# Wi-Fi              21
# Mobile Internet    11
# Dial-up             1
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# Observation:
# - Over 200 shoppers/responders use their mobile data to e-shop while relatively less people use WiFi.
# - Only 1 person used Dial-up connection to e-shop.

# %%
print(data['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '])
plt.xlabel('path of coming to your favourite shopping site')
plt.show()
# Out:
# Search Engine        86
# Content Marketing    10
# Display Adverts       7
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %% [markdown]
# Observations:
# - Most of the people used search engine to arrive at their favourite e-store.
# - less number of shoppers followed content marketers and/or advertisments to arrived at their favourite e-store.

# %%
print(data['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '])
plt.xlabel('reach of online store')
plt.show()
# Out:
# Via application    34
# Search Engine      33
# Direct URL         26
# E-mail              8
# Social Media        2
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %% [markdown]
# Observations:
# - Almost equal no of people/shoppers use search engine and mobile app to access website.
# - Fair amount of shoppers still use direct links(URL's) to access their website.
# - There are still some people who used email ads to reach their preferred shopping website.

# %%
print(data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '],hue=data['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '])
plt.xlabel('page exploration time')
plt.show()
# Out:
# more than 15 mins    48
# 6-10 mins            31
# 11-15 mins           15
# 1-5 mins              5
# Less than 1 min       4
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %% [markdown]
# Observations:
# - maximum people took >15 min to explore e-store to purchase anything using app and direct URL's. while some people used     search engine to purchase products.
# - less no of people took <5 min to purchase using URL's only.
# -  4 people used app and took only <1 min to purchase an item online.
# - in plot it can be seen that from group of ppl that took 6-10 min to purchase items dint used] app but used search engine to purchase, some even used email ads to purchase items.

# %%
print(data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '])
plt.xlabel('preferred payment option')
plt.show()
# Out:
# Credit/Debit cards                    59
# Cash on delivery (CoD)                25
# E-wallets (Paytm, Freecharge etc.)    19
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %% [markdown]
# Observation:
# - Most of the people used credit/debit cards as preferred online payment option while less number used E-wallets.
# - some good number of people used CoD option as well

# %%
print(data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '],hue=data['1Gender of respondent'])
plt.xlabel('abandoning cart items frequency')
plt.show()
# Out:
# Sometimes          64
# Never              17
# Frequently         16
# Very frequently     6
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %% [markdown]
# Observation:
# - In most no. of cases mostly Female shoppers abandoned the cart items then men.This is done sometimes.
# - Equal1(male and female) number of people abandoned their cart items.

# %%
print(data['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '])
plt.xlabel('reason for abandoning cart')
plt.show()
# Out:
# Better alternative offer        49
# Promo code not applicable       21
# Change in price                 15
# Lack of trust                   13
# No preferred mode of payment     5
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %% [markdown]
# Observation:
# - Most people gave the reason of better alternative offer for abandoning items in cart.
# - less no. of people gave reason of no preferred mode of payment for abandoning cart.
# - some people were buying as they had promo code for items they wanted to get online, but since it didnt work they didnt     buy them.

# %%
print(data['18 The content on the website must be easy to read and understand'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['18 The content on the website must be easy to read and understand'])
plt.xlabel('content understanding')
plt.show()
# Out:
# Strongly agree (5)       60
# Agree (4)                33
# Strongly disagree (1)     8
# Indifferent (3)           2
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %% [markdown]
# Observation:
# - Most people strongly agree that the content on the website must be easy to understand while there are minority who disagree to this.
# - 2 people dont care about kind of content on shopping pages.

# %%
print(data['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.xlabel('product comparison with similar selected products should be highlighted')
plt.show()
# Out:
# Strongly agree (5)    40
# Agree (4)             35
# Indifferent (3)       20
# Dis-agree (2)          8
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %% [markdown]
# Observation:
# - Most of the people agree that, similar products to be higlighted in shopping site so there can be better comparison of products while minority of people disagrees to it. Some people dont care about similar product highlighting.

# %%
print(data['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['20 Complete information on listed seller and product being offered is important for purchase decision.'])
plt.xlabel('is listing seller description important?')
plt.show()
# Out:
# Agree (4)                38
# Strongly agree (5)       30
# Indifferent (3)          24
# Dis-agree (2)             8
# Strongly disagree (1)     3
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %% [markdown]
# Observation:
# - Most people agree for complete seller information for product purchase.
# - But still 24 people are unconcerned about seller description.
# - Some disagrees that there should be complete seller information.

# %%
print(data['21 All relevant information on listed products must be stated clearly'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['21 All relevant information on listed products must be stated clearly'])
plt.xlabel('stating relevant information of listed products')
plt.show()
# Out:
# Agree (4)                54
# Strongly agree (5)       37
# Strongly disagree (1)     8
# Dis-agree (2)             4
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %% [markdown]
# Observation:
# - majority of people agrees that relevant information of products should be stated clearly, while minority of people disagrees to it.

# %%
print(data['22 Ease of navigation in website'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['22 Ease of navigation in website'])
plt.xlabel('ease if navigating website')
plt.show()
# Out:
# Strongly agree (5)       51
# Agree (4)                42
# Strongly disagree (1)     8
# Dis-agree (2)             2
# Name: 22 Ease of navigation in website, dtype: int64

# %% [markdown]
# Observation:
# majority of people agrees there should be ease of naviggation within website, while minority of people disagrees to it.

# %%
print(data['25 Convenient Payment methods'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['25 Convenient Payment methods'])
plt.xlabel('payment methods convenience')
plt.show()
# Out:
# Strongly agree (5)    60
# Agree (4)             30
# Dis-agree (2)         13
# Name: 25 Convenient Payment methods, dtype: int64

# %% [markdown]
# Observations:
# - majority/Most of people strongly agrees, there should be convenient payment methods, while minority of people disagrees to it.

# %%
print(data['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'])
plt.xlabel('Trusting retail store to fulfill its part within mentioned time')
plt.show()
# Out:
# Strongly agree (5)    52
# Agree (4)             34
# Disagree (2)          13
# indifferent  (3)       4
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %% [markdown]
# Observations:
# - Most of the people strongly agrees that they trust their e-com website to do its transactional part within         stipulated time.
# - lesser number of people does not agree to it.

# %%
print(data['27 Empathy (readiness to assist with queries) towards the customers'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['27 Empathy (readiness to assist with queries) towards the customers'])
plt.xlabel('Readiness to assist with queries')
plt.show()
# Out:
# Strongly agree (5)       75
# Agree (4)                16
# Strongly disagree (1)     8
# indifferent (3)           4
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %% [markdown]
# Observation:
# - Most people srongly agrees that the e-com website should be always ready to assist customers with their queries. For ex.   1st time buyers always have many queries so e-retail must be ready to assist customers with their various queries.

# %%
print(data['28 Being able to guarantee the privacy of the customer'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['28 Being able to guarantee the privacy of the customer'])
plt.xlabel('guaranteeing privacy of customers')
plt.show()
# Out:
# Strongly agree (5)    69
# Agree (4)             24
# indifferent (3)       10
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %% [markdown]
# Observation:
# - Most people strongly agrees that e-com websites should guarantee the privacy of the customers as customers give their complete adress proof,names and phone numbers including payment card details so e-com websites should preserve customers privacy.

# %%
print(data['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'])
plt.xlabel('response and availability of several communication channels')
plt.show()
# Out:
# Strongly agree (5)       59
# Agree (4)                36
# indifferent (3)           5
# Strongly disagree (1)     3
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %% [markdown]
# Observation:
# - Most of the people strongly agrees that the website should be responsive through several communication channels like sending order details via sms, mail and other channels.

# %%
print(data['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['33 Return and replacement policy of the e-tailer is important for purchase decision'])
plt.xlabel('Return and replacement policy of seller important for purchase decision')
plt.show()
# Out:
# Strongly agree (5)    76
# Agree (4)             20
# Dis-agree (2)          7
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [markdown]
# Observations:
#
# - majority/Most of people strongly agrees, there should be return and replacement policies from seller whih helps them in selecting product, while minority of people disagrees to it.

# %%
print(data['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['35 Displaying quality Information on the website improves satisfaction of customers'])
plt.xlabel('Displaying quality information online improves customer satisfaction')
plt.show()
# Out:
# Strongly agree (5)    49
# Agree (4)             31
# indifferent (3)       23
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %% [markdown]
# Observations:
#
# - majority/Most of the people strongly agrees that website should display quality information whcih improves customer satisfaction inturn helping  them in selecting product, while  23 nos of people disagrees to it.

# %%
print(data['39 Offering a wide variety of listed product in several category'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['39 Offering a wide variety of listed product in several category'])
plt.xlabel('offering wide variety of products')
plt.show()
# Out:
# Strongly agree (5)    42
# Agree (4)             39
# indifferent (3)       20
# Dis-agree (2)          2
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %% [markdown]
# Observations:
#
# - majority/Most of the people agrees that website should offer wide variety of products in several categories , while 20 nos of peopleare unconcerned about it and 2 people disagrees to it.

# %%
print(data['41 Monetary savings'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['41 Monetary savings'])
plt.xlabel('Monetary savings')
plt.show()
# Out:
# Strongly agree (5)    59
# Agree (4)             27
# Disagree (2)          12
# indifferent (3)        5
# Name: 41 Monetary savings, dtype: int64

# %% [markdown]
# Observations:
#
# - majority/Most of the people strongly agrees that buying online saves money, while 12 nos of  people disagrees to it.

# %%
print(data['47 Getting value for money spent'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['47 Getting value for money spent'])
plt.xlabel('Getting value for money spent')
plt.show()
# Out:
# Agree (4)             57
# Strongly agree (5)    32
# indifferent (3)       14
# Name: 47 Getting value for money spent, dtype: int64

# %% [markdown]
# Observations:
#
# - majority/Most of the people strongly agrees that products bought online are value for money, while minority of people thinks its indifferent.

# %%
print(data['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '])
plt.xticks(rotation='vertical')
plt.xlabel('online retailers customers have shopped from')
plt.show()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               16
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                12
# Amazon.in, Flipkart.com                                         12
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in, Flipkart.com, Snapdeal.com                            8
# Amazon.in, Paytm.com                                             5
# Amazon.in                                                        4
# Amazon.in, Flipkart.com, Paytm.com                               2
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %% [markdown]
# Observation:
# - Majority of the people bought products from all the 5 shopping websites mentioned. while there are less/loyal people who  use only amazon to buy their products.

# %%
print(data['Wild variety of product on offer'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Wild variety of product on offer'])
plt.xlabel('Wild variety of product on offer')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in, Flipkart.com                              50
# Amazon.in                                            13
# Amazon.in, Myntra.com                                 8
# Myntra.com                                            8
# Flipkart.com, Myntra.com                              6
# Amazon.in, Flipkart.com, Paytm.com                    6
# Flipkart.com                                          5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     5
# Paytm.com                                             2
# Name: Wild variety of product on offer, dtype: int64

# %% [markdown]
# Observation:
# - Most of the people think amzon and flipkart have wide variety of products on offer.
# - Paytm has the least amount of products on offer.
# - Incase of fashion and lifestyle products myntra has wide variety of products available as shown in graph.

# %%
print(data['Complete, relevant description information of products'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Complete, relevant description information of products'])
plt.xlabel('relevant information of products')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in, Flipkart.com                                         39
# Amazon.in                                                       12
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     8
# Amazon.in, Flipkart.com, Myntra.com                              6
# Snapdeal.com                                                     5
# Flipkart.com, Snapdeal.com                                       5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Amazon.in, Flipkart.com, Snapdeal.com                            2
# Flipkart.com                                                     2
# Name: Complete, relevant description information of products, dtype: int64

# %% [markdown]
# Observation:
# - Most people think that flipkart and amzon provides relevant information of products.

# %%
print(data['Reliability of the website or application'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Reliability of the website or application'])
plt.xlabel('Reliability of the website or application')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in                                            20
# Amazon.in, Flipkart.com                              18
# Amazon.in, Paytm.com, Myntra.com                     16
# Amazon.in, Flipkart.com, Paytm.com                   16
# Amazon.in, Flipkart.com, Snapdeal.com                 7
# Myntra.com                                            6
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com      6
# Paytm.com                                             5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     5
# Flipkart.com                                          4
# Name: Reliability of the website or application, dtype: int64

# %% [markdown]
# Observation:
# - Most people think that flipkart and amzon has most reliable website or app.

# %%
print(data['Speedy order delivery '].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Speedy order delivery '])
plt.xlabel('Speedy order delivery ')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in                                 43
# Amazon.in, Flipkart.com                   30
# Amazon.in, Flipkart.com, Snapdeal.com     16
# Flipkart.com, Myntra.com, Snapdeal.com     5
# Amazon.in, Flipkart.com, Myntra.com        5
# Flipkart.com                               4
# Name: Speedy order delivery , dtype: int64

# %% [markdown]
# Observation:
# - Many people agrees that amazon delivers faster while some people agrees that all the e-shopping website offer speedy delivery.

# %%
print(data['Security of customer financial information'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Security of customer financial information'])
plt.xlabel('Security of customer financial information')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in                                                       16
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    16
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Snapdeal.com                           11
# Amazon.in, Flipkart.com                                         10
# Amazon.in, Paytm.com, Myntra.com                                 8
# Paytm.com                                                        8
# Myntra.com                                                       6
# Amazon.in, Snapdeal.com                                          6
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Amazon.in, Flipkart.com, Paytm.com                               5
# Name: Security of customer financial information, dtype: int64

# %% [markdown]
# Observation:
# - As per some people opinion amazon has better security for customer financial information while equal number of people thinks that all e-com websites offer security of customer financial information.

# %%
print(data['Perceived Trustworthiness'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Perceived Trustworthiness'])
plt.xlabel('Perceived Trustworthiness')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in                                                       25
# Amazon.in, Myntra.com                                           16
# Amazon.in, Flipkart.com, Snapdeal.com                           16
# Amazon.in, Flipkart.com                                         12
# Flipkart.com                                                     9
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                8
# Myntra.com                                                       6
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     6
# Amazon.in, Flipkart.com, Paytm.com                               5
# Name: Perceived Trustworthiness, dtype: int64

# %% [markdown]
# Observations:
# - Looks like amazon is highly trusted by many people followed by Flipkart and myntra.

# %%
print(data['Presence of online assistance through multi-channel'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Presence of online assistance through multi-channel'])
plt.xlabel('Presence of online assistance through multi-channel')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    24
# Amazon.in                                        21
# Amazon.in, Flipkart.com                          15
# Myntra.com                                        8
# Amazon.in, Myntra.com                             8
# Amazon.in, Snapdeal                               8
# Amazon.in, Flipkart.com, Myntra.com               6
# Amazon.in, Flipkart.com, Paytm.com                6
# Paytm.com                                         5
# Flipkart.com                                      2
# Name: Presence of online assistance through multi-channel, dtype: int64

# %% [markdown]
# Observations:
# - As per people opinions Amazon is most selected followed by Flipkart, Myntra as they have presence of online assistance through multi channel.

# %%
print(data['Longer time to get logged in (promotion, sales period)'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Longer time to get logged in (promotion, sales period)'])
plt.xlabel('Longer time to get logged in (promotion, sales period)')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in                                18
# Amazon.in, Flipkart.com                  16
# Paytm.com                                14
# Myntra.com                               13
# Snapdeal.com                             11
# Amazon.in, Flipkart.com, Snapdeal.com    10
# Flipkart.com, Paytm.com                   8
# Flipkart.com, Paytm.com, Snapdeal.com     6
# Amazon.in, Paytm.com                      5
# Flipkart.com                              2
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %% [markdown]
# Observation:
# - It can be seen from the graph Amazon takes much time for customer log-in during sale period,relatively less for Flipkart and Myntra,
# - Snapdeal and Paytm also takes higher time for customer log-in during sale periods.

# %%
print(data['Longer page loading time (promotion, sales period)'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Longer page loading time (promotion, sales period)'])
plt.xlabel('Longer page loading time (promotion, sales period)')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Paytm.com                           27
# Myntra.com                          22
# Flipkart.com                        11
# Snapdeal.com                         8
# Amazon.in, Flipkart.com              8
# Amazon.in, Paytm.com                 6
# Amazon.in, Snapdeal.com              5
# Flipkart.com, Snapdeal.com           5
# Paytm.com, Snapdeal.com              5
# Amazon.in                            4
# Amazon.in, Paytm.com, Myntra.com     2
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %% [markdown]
# Observations:
# - During sale periods PayTm takes most amount of time to load followed by Myntra and then Flipkart.
# - Amzon is relatively faster to load then other mentioned sites.

# %%
print(data['Late declaration of price (promotion, sales period)'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Late declaration of price (promotion, sales period)'])
plt.xlabel('Late declaration of price (promotion, sales period)')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Myntra.com                 30
# Paytm.com                  24
# Flipkart.com               14
# snapdeal.com               14
# Amazon.in                  11
# Amazon.in, Paytm.com        6
# Paytm.com, snapdeal.com     2
# Amazon.in, Flipkart.com     2
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %% [markdown]
# Observations:
# - according to people Myntra declares their promotional or sale prices late followed by Paytm and Flipkart and then by snapdeal as compared to Amazon.

# %%
print(data['Longer delivery period'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Longer delivery period'])
plt.xlabel('Longer delivery period')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Paytm.com                  32
# Snapdeal.com               24
# Flipkart.com               18
# Amazon.in                  11
# Paytm.com, Snapdeal.com    10
# Myntra.com                  8
# Name: Longer delivery period, dtype: int64

# %% [markdown]
# Observation:
# - as seen in plot most people think that Paytm takes most time to deliver  followed by Snapdeal and Flipkart.
# - as per people Myntra and Amzon delivers relatively faster then other sites.

# %%
print(data['Frequent disruption when moving from one page to another'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Frequent disruption when moving from one page to another'])
plt.xlabel('Frequent disruption when moving from one page to another')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Myntra.com                    21
# Amazon.in                     19
# Snapdeal.com                  18
# Paytm.com                     14
# Amazon.in, Flipkart.com       11
# Flipkart.com                  10
# Myntra.com, Snapdeal.com       5
# Flipkart.com, Snapdeal.com     5
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %% [markdown]
# Observation:
# - from the plot it seems that myntra has most desruption followed by amazon and snapdeal when moving from one page to another.
# - Flipkart and Paytm are better compared to other sites incase of page disruptions.

# %%
print(data['Website is as efficient as before'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Website is as efficient as before'])
plt.xlabel('Website is as efficient as before')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in                             35
# Flipkart.com                          17
# Amazon.in, Flipkart.com               15
# Amazon.in, Flipkart.com, Paytm.com    11
# Paytm.com                              8
# Amazon.in, Paytm.com                   7
# Snapdeal.com                           5
# Myntra.com, Snapdeal.com               5
# Name: Website is as efficient as before, dtype: int64

# %% [markdown]
# Observation:
# - Most people think that amazon has most efficent website followed by flipkart and paytm.

# %%
print(data['Which of the Indian online retailer would you recommend to a friend?'].value_counts())
plt.figure(figsize=(15,5))
sns.countplot(data['Which of the Indian online retailer would you recommend to a friend?'])
plt.xlabel('Which of the Indian online retailer would you recommend to a friend?')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Amazon.in                                            28
# Amazon.in, Flipkart.com                              22
# Flipkart.com                                         15
# Amazon.in, Myntra.com                                14
# Amazon.in, Paytm.com, Myntra.com                      8
# Amazon.in, Paytm.com                                  6
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com     5
# Amazon.in, Flipkart.com, Myntra.com                   5
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# Observation:
# - Most of the people have recommended Amazon to their friends and families followed by Flipkart.
