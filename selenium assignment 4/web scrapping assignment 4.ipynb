# %%
import selenium
import pandas as pd
import time

from selenium import webdriver

from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException

import re
from selenium.webdriver.common.by import By

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# - Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# - You need to find following details:
# - A) Rank
# - B) Name
# - C) Artist
# - D) Upload date
# - E) Views

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening wikipedia.com website
url=' https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)
time.sleep(5)

# %%
#scraping ranks of youtube videos

rank=[] 
try:
    ranks=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException:
        rank.append('-')

# %%
len(rank)
# Out:
# 30

# %%
name=[] 
try:
    names=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in names:
        name.append(i.text)
except NoSuchElementException:
        name.append('-')

# %%
Artist=[] 
try:
    Artists=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
    for i in Artists:
        Artist.append(i.text)
except NoSuchElementException:
        Artist.append('-')

# %%
len(Artist)
# Out:
# 30

# %%
upload_date=[] 
try:
    upload_dates=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')
    for i in upload_dates:
        upload_date.append(i.text)
except NoSuchElementException:
        upload_date.append('-')

# %%
views=[] 
try:
    viewss=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')
    for i in viewss:
        views.append(i.text)
except NoSuchElementException:
        views.append('-')

# %%
youtube_videos=pd.DataFrame({'Rank':rank,'Name':name,'Artist':Artist,'Upload date':upload_date,'views':views})
youtube_videos
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                               "Shape of You"[15]
# 4    5.                                  "Bath Song"[17]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                                "Uptown Funk"[24]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[25]
# 9   10.                          "Wheels on the Bus"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                       "Roar"[35]
# ...

# %%
driver.close()

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
# - Url = https://www.bcci.tv/.
# - You need to find following details:
# - A) Match title (I.e. 1st ODI)
# - B) Series
# - C) Place
# - D) Date
# - E) Time
# - Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening guru99.com website
url='  https://www.bcci.tv/'
driver.get(url)
time.sleep(5)

# %%
tab=driver.find_element(By.XPATH,'/html/body/nav/div[1]/button/span[1]')
tab.click()

# %%
int_btn=driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]')
int_btn.click()

# %%
url=[]
link=driver.find_elements(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
for i in link:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.bcci.tv/international/fixtures']

# %%
cat_btn=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[1]/div/div[1]')
cat_btn.click()

# %%
women_select=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[1]/div/div[2]/div[3]')
women_select.click()

# %%
tour_tab=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[2]/div/div[1]')
tour_tab.click()

# %%
aus_tour=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[2]/div/div[2]/div[3]')
aus_tour.click()

# %%
series=[]
for i in url:
    driver.get(i)
    time.sleep(10)
    try:
        seriess=driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
        for u in seriess:
            series.append(u.text)
    except NoSuchElementException:
        series.append('-')

# %%
series
# Out:
# ['AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022']

# %%
title=[]
for i in url:
    driver.get(i)
    time.sleep(10)
    try:
        titles=driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
        for u in titles:
            title.append(u.text)
    except NoSuchElementException:
        title.append('-')

# %%
title
# Out:
# ['1st T20I -', '2nd T20I -', '3rd T20I -', '4th T20I -', '5th T20I -']

# %%
date=[]
for i in url:
    driver.get(i)
    time.sleep(10)
    try:
        titles=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
        for u in titles:
            date.append(u.text)
    except NoSuchElementException:
        date.append('-')

# %%
date
# Out:
# ['9 DEC 2022', '11 DEC 2022', '14 DEC 2022', '17 DEC 2022', '20 DEC 2022']

# %%
times=[]
for i in url:
    driver.get(i)
    time.sleep(10)
    try:
        titles=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
        for u in titles:
            times.append(u.text)
    except NoSuchElementException:
        times.append('-')

# %%
times
# Out:
# ['7:00 PM IST', '7:00 PM IST', '7:00 PM IST', '7:00 PM IST', '7:00 PM IST']

# %%
place=[]
for i in url:
    driver.get(i)
    time.sleep(10)
    try:
        titles=driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]')
        for u in titles:
            place.append(u.text.split(' ')[-1:])
    except NoSuchElementException:
        place.append('-')

# %%
place
# Out:
# [['MUMBAI'], ['MUMBAI'], ['Mumbai'], ['Mumbai'], ['Mumbai']]

# %%
bcci_data=pd.DataFrame({'Match title':title,'Series':series,'Place':place,'Date':date,'Time':time})
bcci_data
# Out:
#   Match title                              Series     Place         Date  \
# 0  1st T20I -  AUSTRALIA WOMEN TOUR OF INDIA 2022  [MUMBAI]   9 DEC 2022
# 1  2nd T20I -  AUSTRALIA WOMEN TOUR OF INDIA 2022  [MUMBAI]  11 DEC 2022
# 2  3rd T20I -  AUSTRALIA WOMEN TOUR OF INDIA 2022  [Mumbai]  14 DEC 2022
# 3  4th T20I -  AUSTRALIA WOMEN TOUR OF INDIA 2022  [Mumbai]  17 DEC 2022
# 4  5th T20I -  AUSTRALIA WOMEN TOUR OF INDIA 2022  [Mumbai]  20 DEC 2022
#
#                          Time
# 0  <module 'time' (built-in)>
# 1  <module 'time' (built-in)>
# 2  <module 'time' (built-in)>
# 3  <module 'time' (built-in)>
# 4  <module 'time' (built-in)>

# %%
driver.close()

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.**
# - Url = https://www.guru99.com/
# - You need to find following details:
# - A) Name
# - B) Description
# - Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening guru99.com website
url=' https://www.guru99.com/'
driver.get(url)
time.sleep(5)

# %%
search_bar=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input')
search_bar.send_keys('Selenium exception handling')

search_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button')
search_button.click()

# %%
search_option=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/div[1]/div[6]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a')
search_option.click()

# %%
#scraping url
url=[]

brand_url=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/div[1]/div[6]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a')
for i in brand_url:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.guru99.com/exception-handling-selenium.html']

# %%
name=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        names=driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]/p/strong')
        for i in names:
            name.append(i.text)
    except NoSuchElementException:
        name.append('-')

# %%
len(name)
# Out:
# 47

# %%
name[:41]
# Out:
# ['1. ElementNotVisibleException:',
#  '2. ElementNotSelectableException:',
#  '3. NoSuchElementException:',
#  '4. NoSuchFrameException:',
#  '5. NoAlertPresentException:',
#  '6. NoSuchWindowException:',
#  '7. StaleElementReferenceException:',
#  '8. SessionNotFoundException:',
#  '9. TimeoutException:',
#  '10. WebDriverException:',
#  '11. ConnectionClosedException:',
#  '12. ElementClickInterceptedException:',
#  '13. ElementNotInteractableException:',
#  '14. ErrorInResponseException:',
#  '15. ErrorHandler.UnknownServerException:',
#  '16. ImeActivationFailedException:',
#  '17. ImeNotAvailableException:',
#  '18. InsecureCertificateException:',
#  '19. InvalidArgumentException:',
#  '20. InvalidCookieDomainException:',
#  '21. InvalidCoordinatesException:',
#  '22. InvalidElementStateException:',
#  '23. InvalidSessionIdException:',
#  '24. InvalidSwitchToTargetException:',
#  '25. JavascriptException:',
#  '26. JsonException:',
#  '27. NoSuchAttributeException:',
# ...

# %%
descriptions=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        description=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/p')
        for i in description:
            descriptions.append(i.text.split(':')[1:])
    except NoSuchElementException:
        descriptions.append('-')

# %%
len(descriptions)
# Out:
# 53

# %%
descriptions[:41]
# Out:
# [[' This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.'],
#  [' This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.'],
#  [' This Exception occurs if an element could not be found.'],
#  [' This Exception occurs if the frame target to be switched to does not exist.'],
#  [' This Exception occurs when you switch to no presented alert.'],
#  [' This Exception occurs if the window target to be switch does not exist.'],
#  [' This Selenium exception occurs happens when the web element is detached from the current DOM.'],
#  [' The WebDriver is acting after you quit the browser.'],
#  [' Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn’t found in the specified time.'],
#  [' This Exception takes place when the WebDriver is acting right after you close the browser.'],
# ...

# %%
data=pd.DataFrame({'Exception name':name[:41],'description':descriptions[:41]})
data
# Out:
#                               Exception name  \
# 0             1. ElementNotVisibleException:
# 1          2. ElementNotSelectableException:
# 2                 3. NoSuchElementException:
# 3                   4. NoSuchFrameException:
# 4                5. NoAlertPresentException:
# 5                  6. NoSuchWindowException:
# 6         7. StaleElementReferenceException:
# 7               8. SessionNotFoundException:
# 8                       9. TimeoutException:
# 9                    10. WebDriverException:
# 10            11. ConnectionClosedException:
# 11     12. ElementClickInterceptedException:
# 12      13. ElementNotInteractableException:
# 13             14. ErrorInResponseException:
# 14  15. ErrorHandler.UnknownServerException:
# 15         16. ImeActivationFailedException:
# 16             17. ImeNotAvailableException:
# 17         18. InsecureCertificateException:
# 18             19. InvalidArgumentException:
# 19         20. InvalidCookieDomainException:
# ...

# %%
driver.close()

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.**
# - Url = http://statisticstimes.com/
# - You have to find following details:
# - A) Rank
# - B) State
# - C) GSDP(18-19)- at current prices
# - D) GSDP(19-20)- at current prices
# - E) Share(18-19)
# - F) GDP($ billion)
# - Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening statisticstime.com page
url='https://www.statisticstimes.com/'
driver.get(url)
time.sleep(5)

# %%
drop_down=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
drop_down.click()

# %%
india_click=driver.find_element(By.XPATH,'//div[@class="dropdown"][2]/div/a[3]')
india_click.click()

# %%
url=[]
link=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
for i in link:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.statisticstimes.com/economy/india/indian-states-gdp.php']

# %%
indian_states=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
indian_states.click()

# %%
rank=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        ranks=driver.find_elements(By.XPATH,'//td[@class="data1"]')
        for u in ranks:
            rank.append(u.text)
    except NoSUchElementException:
        rank.append('-')

# %%
state=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        states=driver.find_elements(By.XPATH,'//td[@class="name"]')
        for u in states:
            state.append(u.text)
    except NoSUchElementException:
        state.append('-')

# %%
gsdp1920=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        gsdp1920s=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[3]')
        for u in gsdp1920s:
            gsdp1920.append(u.text)
    except NoSUchElementException:
        gsdp1920.append('-')

# %%
gsdp1819=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        gsdp1819s=driver.find_elements(By.XPATH,'//td[@class="data sorting_1"]')
        for u in gsdp1819s:
            gsdp1819.append(u.text)
    except NoSUchElementException:
        gsdp1819.append('-')

# %%
share=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        shares=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[5]')
        for u in shares:
            share.append(u.text)
    except NoSuchElementException:
        share.append('-')

# %%
GDP=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        GDPs=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[6]')
        for u in GDPs:
            GDP.append(u.text)
    except NoSuchElementException:
        GDP.append('-')

# %%
statistics=pd.DataFrame({'Rank':rank[:33],'State':state[:33],'GSDP 19-20':gsdp1920[:33],'GSDP 18-19':gsdp1819[:33],
                         'Share':share[:33],'GDP':GDP[:33]})
statistics
# Out:
#    Rank                      State GSDP 19-20 GSDP 18-19   Share      GDP
# 0     1                Maharashtra          -  2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%  240.726
# 3     4                    Gujarat          -  1,502,899   7.96%  228.290
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%  226.806
# 5     6                West Bengal  1,253,832  1,089,898   5.77%  165.556
# 6     7                  Rajasthan  1,020,989    942,586   4.99%  143.179
# 7     8             Andhra Pradesh    972,782    862,957   4.57%  131.083
# 8     9                  Telangana    969,604    861,031   4.56%  130.791
# 9    10             Madhya Pradesh    906,672    809,592   4.29%  122.977
# 10   11                     Kerala          -    781,653   4.14%  118.733
# 11   12                      Delhi    856,112    774,870   4.10%  117.703
# ...

# %%
driver.close()

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
# - Url = https://github.com/
# - You have to find the following details:
# - A) Repository title
# - B) Repository description
# - C) Contributors count
# - D) Language used

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening github.com page
url='https://github.com/'
driver.get(url)
time.sleep(5)

# %%
tab_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[1]/div[2]/button/span')
tab_btn.click()

# %%
os_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
os_btn.click()

# %%
url=[]
link=driver.find_elements(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')
for i in link:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://github.com/trending']

# %%
trending_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')
trending_btn.click()

# %%
#extracting Repository title
title=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        title_tags=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
        for u in title_tags:
            title.append(u.text.split("/")[1])
    except NoSuchElementException:
        title.append('-')

# %%
len(title)
# Out:
# 25

# %%
title
# Out:
# [' InvokeAI',
#  ' ml-stable-diffusion',
#  ' snarkOS',
#  ' misskey',
#  ' klipper',
#  ' cs-self-learning',
#  ' whatsapp-gpt',
#  ' awesome-english-ebooks',
#  ' Book4_Power-of-Matrix',
#  ' go-coffeeshop',
#  ' monica',
#  ' lede',
#  ' awesome-advent-of-code',
#  ' palera1n',
#  ' create-t3-app',
#  ' easytrojan',
#  ' openai-quickstart-node',
#  ' PowerToys',
#  ' go-clean-template',
#  ' zfs',
#  ' cloudstream',
#  ' advent-of-code-rust',
#  ' You-Dont-Know-JS',
#  ' openai-quickstart-python',
#  ' xilem']

# %%
#extracting Repository description
description=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        description_tags=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
        for u in description_tags:
            description.append(u.text)
    except NoSuchElementException:
        description.append('-')

# %%
len(description)
# Out:
# 24

# %%
description
# Out:
# ['This version of Stable Diffusion features a slick WebGUI, an interactive command-line script that combines text2img and img2img functionality in a "dream bot" style interface, and multiple features and other enhancements. For more info, see the website link below.',
#  'Stable Diffusion with Core ML on Apple Silicon',
#  'A Decentralized Operating System for ZK Applications',
#  '🌎 An interplanetary microblogging platform 🚀',
#  'Klipper is a 3d-printer firmware',
#  '计算机自学指南',
#  '经济学人(含音频)、纽约客、卫报、连线、大西洋月刊等英语杂志免费下载,支持epub、mobi、pdf格式, 每周更新',
#  'Book_4_《矩阵力量》 | 鸢尾花书：从加减乘除到机器学习；本册有，584幅图，81个代码文件，其中18个Streamlit App；状态：清华社五审五校中；Github稿件基本稳定，欢迎提意见，会及时修改',
#  '☕ A practical event-driven microservices demo built with Golang. Nomad, Consul Connect, Vault, and Terraform for deployment',
#  'Personal CRM. Remember everything about your friends, family and business relationships.',
#  "Lean's LEDE source",
# ...

# %%
#extracting Repository description
ccount=[]
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        ccounts=driver.find_elements(By.XPATH,'//img[@class="avatar mb-1 avatar-user"]')
        for u in ccounts:
            ccount.append(u.get_attribute('src'))
    except NoSuchElementException:
        ccount.append('-')

# %%
ccount
# Out:
# ['https://avatars.githubusercontent.com/u/111189?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/40327258?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/4822129?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/3865161?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/54517381?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/64497909?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/6166296?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/9260812?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/14917648?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/3750347?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/13221615?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/8600837?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/4439005?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/30769358?s=40&v=4',
#  'https://avatars.githubusercontent.com/u/10798641?s=40&v=4',
# ...

# %%
#extracting Repository languages
language=[]
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        languages=driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
        for u in languages:
            language.append(u.text)
    except NoSuchElementException:
        language.append('-')

# %%
language
# Out:
# ['Jupyter Notebook',
#  'Python',
#  'Rust',
#  'TypeScript',
#  'C',
#  'HTML',
#  'Go',
#  'CSS',
#  'Python',
#  'Go',
#  'PHP',
#  'C',
#  'Shell',
#  'TypeScript',
#  'Shell',
#  'JavaScript',
#  'C#',
#  'Go',
#  'C',
#  'Kotlin',
#  'Rust',
#  'CSS',
#  'Rust']

# %%
driver.close()

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.
# - Url = https:/www.billboard.com/
# - You have to find the following details:
# - A) Song name
# - B) Artist name
# - C) Last week rank
# - D) Peak rank
# - E) Weeks on board
# - Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening github.com page
url='https:/www.billboard.com/'
driver.get(url)
time.sleep(2)

# %%
tab_btn=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button')
tab_btn.click()

# %%
chart_btn=driver.find_element(By.XPATH,'/html/body/div[3]/div[7]/div/div/div/ul/li[1]/h3/a')
chart_btn.click()

# %%
#getting link of the top100 page
url=[]
link=driver.find_elements(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
for i in link:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.billboard.com/charts/hot-100/']

# %%
top100_btn=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
top100_btn.click()

# %%
name=[]
for i in url:
    driver.get(i)
    time.sleep(3)
    try:
        names=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li/h3')
        for u in names:
            name.append(u.text)
    except NoSuchElementException:
        name.append('-')

# %%
name
# Out:
# ['Anti-Hero',
#  'Rich Flex',
#  'Unholy',
#  'Bad Habit',
#  'All I Want For Christmas Is You',
#  "Rockin' Around The Christmas Tree",
#  "I'm Good (Blue)",
#  'As It Was',
#  'Jingle Bell Rock',
#  'A Holly Jolly Christmas',
#  'Lift Me Up',
#  'Die For You',
#  'You Proof',
#  'Under The Influence',
#  'Super Freaky Girl',
#  'Cuff It',
#  'Something In The Orange',
#  'I Like You (A Happier Song)',
#  "It's The Most Wonderful Time Of The Year",
#  'Wasted On You',
#  'Just Wanna Rock',
#  'Tomorrow 2',
#  'Last Christmas',
#  'Made You Look',
#  'Vegas',
#  'Lavender Haze',
#  "I Ain't Worried",
#  'Titi Me Pregunto',
#  'Wait For U',
#  'Major Distribution',
#  'Spin Bout U',
#  'The Kind Of Love We Make',
#  'Sunroof',
#  'The Christmas Song (Merry Christmas To You)',
#  'Golden Hour',
#  'Jimmy Cooks',
#  'Circo Loco',
#  'She Had Me At Heads Carolina',
#  'On BS',
#  'Sleigh Ride',
#  'Let It Snow, Let It Snow, Let It Snow',
#  'Feliz Navidad',
# ...

# %%
artist=[]
for i in url:
    driver.get(i)
    time.sleep(5)
    try:
        artists=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[1]/span')
        for u in artists:
            artist.append(u.text)
    except NoSuchElementException:
        artist.append('-')

# %%
artist
# Out:
# ['Taylor Swift',
#  'Drake & 21 Savage',
#  'Sam Smith & Kim Petras',
#  'Steve Lacy',
#  'Mariah Carey',
#  'Brenda Lee',
#  'David Guetta & Bebe Rexha',
#  'Harry Styles',
#  'Bobby Helms',
#  'Burl Ives',
#  'Rihanna',
#  'The Weeknd',
#  'Morgan Wallen',
#  'Chris Brown',
#  'Nicki Minaj',
#  'Beyonce',
#  'Zach Bryan',
#  'Post Malone Featuring Doja Cat',
#  'Andy Williams',
#  'Morgan Wallen',
#  'Lil Uzi Vert',
#  'GloRilla & Cardi B',
#  'Wham!',
#  'Meghan Trainor',
#  'Doja Cat',
#  'Taylor Swift',
#  'OneRepublic',
#  'Bad Bunny',
#  'Future Featuring Drake & Tems',
#  'Drake & 21 Savage',
#  'Drake & 21 Savage',
#  'Luke Combs',
#  'Nicky Youre & dazy',
#  'Nat King Cole',
#  'JVKE',
#  'Drake Featuring 21 Savage',
#  'Drake & 21 Savage',
#  'Cole Swindell',
#  'Drake & 21 Savage',
#  'The Ronettes',
#  'Dean Martin',
#  'Jose Feliciano',
#  'Perry Como And The Fontane Sisters With Mitchell Ayres And His Orchestra',
#  'Lizzo',
#  'Stephen Sanchez',
# ...

# %%
lwr=[]
for i in url:
    driver.get(i)
    time.sleep(5)
    try:
        lwrs=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[4]/span')
        for u in lwrs:
            lwr.append(u.text)
    except NoSuchElementException:
        lwr.append('-')

# %%
lwr
# Out:
# ['1',
#  '2',
#  '3',
#  '4',
#  '25',
#  '41',
#  '7',
#  '5',
#  '50',
#  '-',
#  '8',
#  '12',
#  '13',
#  '17',
#  '11',
#  '20',
#  '19',
#  '16',
#  '-',
#  '23',
#  '47',
#  '29',
#  '-',
#  '40',
#  '18',
#  '21',
#  '24',
#  '32',
#  '30',
#  '6',
#  '9',
#  '36',
#  '28',
#  '-',
#  '42',
#  '27',
#  '14',
#  '31',
#  '10',
#  '-',
#  '-',
#  '-',
#  '-',
#  '38',
#  '56',
#  '43',
#  '15',
#  '-',
#  '54',
#  '35',
#  '46',
#  '33',
#  '51',
#  '57',
#  '60',
#  '53',
#  '59',
#  '39',
#  '61',
#  '66',
#  '63',
#  '22',
#  '55',
#  '64',
#  '45',
#  '26',
#  '48',
#  '34',
#  '49',
#  '37',
#  '74',
#  '68',
#  '62',
#  '75',
#  '71',
#  '91',
#  '52',
#  '65',
#  '79',
#  '78',
#  '76',
#  '82',
#  '85',
#  '70',
#  '58',
#  '86',
#  '90',
#  '-',
#  '73',
#  '84',
#  '87',
#  '77',
#  '83',
#  '92',
#  '-',
#  '72',
#  '-',
#  '99',
#  '67',
#  '69']

# %%
peak_pos=[]
for i in url:
    driver.get(i)
    time.sleep(5)
    try:
        peak_poss=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[5]/span')
        for u in peak_poss:
            peak_pos.append(u.text)
    except NoSuchElementException:
        peak_pos.append('-')

# %%
peak_pos
# Out:
# ['1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '2',
#  '7',
#  '1',
#  '3',
#  '4',
#  '2',
#  '12',
#  '5',
#  '14',
#  '1',
#  '13',
#  '12',
#  '3',
#  '5',
#  '9',
#  '21',
#  '9',
#  '7',
#  '24',
#  '10',
#  '2',
#  '6',
#  '5',
#  '1',
#  '3',
#  '5',
#  '8',
#  '4',
#  '11',
#  '35',
#  '1',
#  '8',
#  '16',
#  '4',
#  '10',
#  '8',
#  '6',
#  '12',
#  '1',
#  '38',
#  '22',
#  '6',
#  '12',
#  '29',
#  '6',
#  '6',
#  '5',
#  '51',
#  '24',
#  '41',
#  '52',
#  '57',
#  '3',
#  '35',
#  '50',
#  '31',
#  '7',
#  '11',
#  '32',
#  '9',
#  '9',
#  '8',
#  '12',
#  '4',
#  '11',
#  '44',
#  '33',
#  '10',
#  '46',
#  '58',
#  '76',
#  '16',
#  '7',
#  '57',
#  '21',
#  '4',
#  '74',
#  '72',
#  '13',
#  '14',
#  '86',
#  '69',
#  '88',
#  '14',
#  '63',
#  '84',
#  '15',
#  '42',
#  '67',
#  '95',
#  '53',
#  '88',
#  '98',
#  '15',
#  '18']

# %%
woc=[]
for i in url:
    driver.get(i)
    time.sleep(5)
    try:
        wocs=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[6]/span')
        for u in wocs:
            woc.append(u.text)
    except NoSuchElementException:
        woc.append('-')

# %%
woc
# Out:
# ['5',
#  '3',
#  '9',
#  '21',
#  '53',
#  '47',
#  '13',
#  '34',
#  '44',
#  '27',
#  '4',
#  '17',
#  '28',
#  '11',
#  '15',
#  '15',
#  '31',
#  '25',
#  '28',
#  '54',
#  '6',
#  '9',
#  '26',
#  '5',
#  '25',
#  '5',
#  '24',
#  '29',
#  '30',
#  '3',
#  '3',
#  '23',
#  '26',
#  '33',
#  '13',
#  '23',
#  '3',
#  '26',
#  '3',
#  '17',
#  '20',
#  '21',
#  '13',
#  '32',
#  '21',
#  '11',
#  '3',
#  '16',
#  '30',
#  '5',
#  '13',
#  '5',
#  '12',
#  '24',
#  '15',
#  '14',
#  '20',
#  '5',
#  '17',
#  '13',
#  '21',
#  '3',
#  '4',
#  '9',
#  '5',
#  '3',
#  '5',
#  '3',
#  '5',
#  '3',
#  '23',
#  '12',
#  '5',
#  '19',
#  '11',
#  '2',
#  '3',
#  '5',
#  '9',
#  '7',
#  '6',
#  '12',
#  '14',
#  '5',
#  '3',
#  '2',
#  '17',
#  '1',
#  '5',
#  '11',
#  '5',
#  '5',
#  '16',
#  '14',
#  '1',
#  '3',
#  '4',
#  '2',
#  '3',
#  '3']

# %%
billboard_100=pd.DataFrame({'Song Name':name,'Artist':artist,'Last week rank':lwr,
                           'Peak postion':peak_pos,'Weeks on chart':woc})
billboard_100
# Out:
#                           Song Name                  Artist Last week rank  \
# 0                         Anti-Hero            Taylor Swift              1
# 1                         Rich Flex       Drake & 21 Savage              2
# 2                            Unholy  Sam Smith & Kim Petras              3
# 3                         Bad Habit              Steve Lacy              4
# 4   All I Want For Christmas Is You            Mariah Carey             25
# ..                              ...                     ...            ...
# 95                      Die For You                    Joji             72
# 96                        Down Home            Jimmie Allen              -
# 97               Going, Going, Gone              Luke Combs             99
# 98              Middle Of The Ocean                   Drake             67
# 99                         More M’s       Drake & 21 Savage             69
#
#    Peak postion Weeks on chart
# 0             1              5
# ...

# %%
driver.close()

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
# - Url = https://www.naukri.com/
# - You have to find the following details:
# - A) Name
# - B) Designation
# - C) Company
# - D) Skills they hire for
# - E) Location
# - Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# - click on search. All this should be done through code

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening naukri.com website
url='  https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)
time.sleep(5)

# %%
search_option=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
search_option.send_keys('Data Science')

# %%
search_button= driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
search_button.click()

# %%
url=[]
link=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[2]/div/div/div/ul/li[1]/a')
for i  in link:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.naukri.com/recruiters/browse-all-recruiters']

# %%
name=[]
time.sleep(5)
try:
    names=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
    for u in names:
        name.append(u.text)
except NoSuchElementException:
    name.append('-')

# %%
name
# Out:
# ['Aakash Harit',
#  'shravan Kumar Gaddam',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'subhas patel',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Institute for Financial Management and Resear',
#  'Balu Ramesh',
#  'Asif Lucknowi',
#  'InstaFinancials',
#  'Kalpana Dumpala',
#  'Mubarak',
#  'Kushal Rastogi',
#  'Mahesh Babu Channa',
#  'Vaishnavi Kudalkar',
#  'Priyanka Akiri',
#  'Kapil Devang',
#  'Sakshi Chhikara',
#  'Ruchi Dhote',
#  'Manisha Yadav',
#  'Riya Rajesh',
#  'Rashmi Bhattacharjee',
#  'Faizan Kareem',
#  'Rithika dadwal',
#  'Sandhya Khandagale',
#  'Shaun Rao',
#  'Azahar Shaikh',
#  'Manas',
#  'kumar',
#  'Sunil Vedula',
#  'Rajat Kumar',
#  'Dhruv Dev Dubey',
#  'Jayanth N',
#  'Daniel Vaz',
#  'Avodha',
#  'Priya Khare',
#  'Amit Sharma',
#  'Kanan',
#  'Shashikant Chaudhary',
#  'Brad',
#  'Rutuja Pawar',
#  'Madhusudhan Sridhar',
#  'Ankit Sinha',
#  'Gaurav Chouhan',
#  'Rashi Kacker',
#  'Ashwini',
#  'Balaji Kolli',
# ...

# %%
designation=[]
time.sleep(5)
try:
    designations=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
    for u in designations:
        designation.append(u.text)
except NoSuchElementException:
    designation.append('-')

# %%
designation
# Out:
# ['HR Manager',
#  'Company Recruiter',
#  'Company HR',
#  'Company Recruiter',
#  'Founder CEO',
#  'Recruitment Lead Consultant',
#  'Programme Manager',
#  'HR Administrator',
#  'Director',
#  'Human Resource',
#  'Executive Hiring',
#  'Company HR',
#  'Company HR',
#  'HR Team Lead',
#  'HR Executive',
#  'HR Manager',
#  'HR Manager',
#  'Assistant Manager HR',
#  'Senior Executive Talent Acquisition',
#  'HR Executive',
#  'Manager Talent Acquisition',
#  'HR Head',
#  'HR MANAGER',
#  'HR Recruiter',
#  'HR Recruiter',
#  'Manager Human Resources',
#  'Company Recruiter',
#  'Lead Talent acquisition',
#  'Proprietor',
#  'CEO',
#  'Founder CEO',
#  'Company Recruitment Head',
#  'Project Manager',
#  'Partner',
#  'Business Development Associate',
#  'Senior Manager',
#  'Consultant',
#  'senior technology instructor',
#  'HR Recruiter/HR Excutive',
#  'Manager, Technical Recruiting',
#  'Technical Recruiter',
#  'Erp Implementer',
#  'Head Analytics',
# ...

# %%
company=[]
time.sleep(5)
try:
    companys=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/a[2]')
    for u in companys:
        company.append(u.text)
except NoSuchElementException:
    company.append('-')

# %%
len(company)
# Out:
# 50

# %%
location=[]
time.sleep(5)
try:
    locations=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/span/small')
    for u in locations:
        location.append(u.text)
except NoSuchElementException:
    location.append('-')

# %%
len(location)
# Out:
# 48

# %%
skill=[]
time.sleep(5)
try:
    skills=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
    for u in skills:
        skill.append(u.text)
except NoSuchElementException:
    skill.append('-')

# %%
len(skill)
# Out:
# 50

# %%
naukri_data=pd.DataFrame({'Name':name[:48],'Designation':designation[:48],'Company':company[:48],'Skills they hire for':skill[:48]
                         ,'Location':location[:48]})
naukri_data
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                             Vaishnavi Kudalkar
# 15                                 Priyanka Akiri
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %%
driver.close()

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# - Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# - You have to find the following details:
# - A) Book name
# - B) Author name
# - C) Volumes sold
# - D) Publisher
# - E) Genre

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening guardian.com website
url=' https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)
time.sleep(5)

# %%
url=[]

link=driver.find_elements(By.XPATH,'/html/body/div/div[2]/div[1]/div[2]/div/a[1]')
for i in link:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare#list']

# %%
name=[]
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        names=driver.find_elements(By.XPATH,'/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[2]')
        for u in names:
            name.append(u.text)
    except NoSuchElementException:
        name.append('-')

# %%
name
# Out:
# ['Da Vinci Code,The',
#  'Harry Potter and the Deathly Hallows',
#  "Harry Potter and the Philosopher's Stone",
#  'Harry Potter and the Order of the Phoenix',
#  'Fifty Shades of Grey',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Angels and Demons',
#  "Harry Potter and the Half-blood Prince:Children's Edition",
#  'Fifty Shades Darker',
#  'Twilight',
#  'Girl with the Dragon Tattoo,The:Millennium Trilogy',
#  'Fifty Shades Freed',
#  'Lost Symbol,The',
#  'New Moon',
#  'Deception Point',
#  'Eclipse',
#  'Lovely Bones,The',
#  'Curious Incident of the Dog in the Night-time,The',
#  'Digital Fortress',
#  'Short History of Nearly Everything,A',
#  'Girl Who Played with Fire,The:Millennium Trilogy',
#  'Breaking Dawn',
#  'Very Hungry Caterpillar,The:The Very Hungry Caterpillar',
#  'Gruffalo,The',
#  "Jamie's 30-Minute Meals",
#  'Kite Runner,The',
#  'One Day',
# ...

# %%
a_name=[]
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        a_names=driver.find_elements(By.XPATH,'/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[3]')
        for u in a_names:
            a_name.append(u.text)
    except NoSuchElementException:
        a_name.append('-')

# %%
a_name
# Out:
# ['Brown, Dan',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'James, E. L.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Brown, Dan',
#  'Rowling, J.K.',
#  'James, E. L.',
#  'Meyer, Stephenie',
#  'Larsson, Stieg',
#  'James, E. L.',
#  'Brown, Dan',
#  'Meyer, Stephenie',
#  'Brown, Dan',
#  'Meyer, Stephenie',
#  'Sebold, Alice',
#  'Haddon, Mark',
#  'Brown, Dan',
#  'Bryson, Bill',
#  'Larsson, Stieg',
#  'Meyer, Stephenie',
#  'Carle, Eric',
#  'Donaldson, Julia',
#  'Oliver, Jamie',
#  'Hosseini, Khaled',
#  'Nicholls, David',
#  'Hosseini, Khaled',
#  'Larsson, Stieg',
#  'Niffenegger, Audrey',
#  'McEwan, Ian',
#  'Fielding, Helen',
#  'Clarkson, Jeremy',
#  'Bernieres, Louis de',
#  'Kay, Peter',
#  'Martel, Yann',
#  'Stephenson, Pamela',
#  'Pelzer, Dave',
#  'Donaldson, Julia',
#  'McCourt, Frank',
#  'Faulks, Sebastian',
#  'Pullman, Philip',
#  'Mosse, Kate',
#  'Rowling, J.K.',
#  'Stockett, Kathryn',
#  'Parsons, Tony',
# ...

# %%
volume=[]
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        volums=driver.find_elements(By.XPATH,'/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[4]')
        for u in volums:
            volume.append(u.text)
    except NoSuchElementException:
        volume.append('-')

# %%
volume
# Out:
# ['5,094,805',
#  '4,475,152',
#  '4,200,654',
#  '4,179,479',
#  '3,758,936',
#  '3,583,215',
#  '3,484,047',
#  '3,377,906',
#  '3,193,946',
#  '2,950,264',
#  '2,479,784',
#  '2,315,405',
#  '2,233,570',
#  '2,193,928',
#  '2,183,031',
#  '2,152,737',
#  '2,062,145',
#  '2,052,876',
#  '2,005,598',
#  '1,979,552',
#  '1,928,900',
#  '1,852,919',
#  '1,814,784',
#  '1,787,118',
#  '1,783,535',
#  '1,781,269',
#  '1,743,266',
#  '1,629,119',
#  '1,616,068',
#  '1,583,992',
#  '1,555,135',
#  '1,546,886',
#  '1,539,428',
#  '1,508,205',
#  '1,489,403',
#  '1,352,318',
#  '1,310,207',
#  '1,310,176',
#  '1,231,957',
#  '1,217,712',
#  '1,208,711',
#  '1,204,058',
#  '1,184,967',
#  '1,181,503',
#  '1,181,093',
#  '1,153,181',
#  '1,132,336',
#  '1,130,802',
#  '1,126,337',
#  '1,115,549',
#  '1,108,328',
#  '1,107,379',
#  '1,104,403',
#  '1,092,349',
#  '1,090,847',
#  '1,087,262',
#  '1,054,196',
#  '1,037,160',
#  '1,023,688',
#  '1,015,956',
#  '1,009,873',
#  '1,004,414',
# ...

# %%
publisher=[]
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        publishers=driver.find_elements(By.XPATH,'/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[5]')
        for u in publishers:
            publisher.append(u.text)
    except NoSuchElementException:
        publisher.append('-')

# %%
publisher
# Out:
# ['Transworld',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Random House',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Transworld',
#  'Bloomsbury',
#  'Random House',
#  'Little, Brown Book',
#  'Quercus',
#  'Random House',
#  'Transworld',
#  'Little, Brown Book',
#  'Transworld',
#  'Little, Brown Book',
#  'Pan Macmillan',
#  'Random House',
#  'Transworld',
#  'Transworld',
#  'Quercus',
#  'Little, Brown Book',
#  'Penguin',
#  'Pan Macmillan',
#  'Penguin',
#  'Bloomsbury',
#  'Hodder & Stoughton',
#  'Bloomsbury',
#  'Quercus',
#  'Random House',
#  'Random House',
#  'Pan Macmillan',
#  'Penguin',
#  'Random House',
#  'Random House',
#  'Canongate',
#  'HarperCollins',
#  'Orion',
#  'Pan Macmillan',
#  'HarperCollins',
#  'Random House',
#  'Scholastic Ltd.',
#  'Orion',
#  'Bloomsbury',
#  'Penguin',
#  'HarperCollins',
#  'Random House',
#  'Little, Brown Book',
#  'Headline',
#  'HarperCollins',
#  'Penguin',
#  'Orion',
#  'Bloomsbury',
# ...

# %%
genre=[]
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        genres=driver.find_elements(By.XPATH,'/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[6]')
        for u in genres:
            genre.append(u.text)
    except NoSuchElementException:
        genre.append('-')

# %%
genre
# Out:
# ['Crime, Thriller & Adventure',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Romance & Sagas',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Crime, Thriller & Adventure',
#  "Children's Fiction",
#  'Romance & Sagas',
#  'Young Adult Fiction',
#  'Crime, Thriller & Adventure',
#  'Romance & Sagas',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Crime, Thriller & Adventure',
#  'Popular Science',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'Picture Books',
#  'Picture Books',
#  'Food & Drink: General',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Crime, Thriller & Adventure',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
# ...

# %%
books=pd.DataFrame({'Book name':name,'Author name':a_name,'Volume sold':volume,'Publisher':publisher,'Genre':genre})
books
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
# - Url = https://www.imdb.com/list/ls095964455/
# - You have to find the following details:
# - A) Name
# - B) Year span
# - C) Genre
# - D) Run time
# - E) Ratings
# - F) Votes

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening guardian.com website
url=' https://www.imdb.com/list/ls095964455/'
driver.get(url)
time.sleep(5)

# %%
name=[]
names=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
for i in names:
    name.append(i.text)

# %%
name
# Out:
# ['Game of Thrones',
#  'Stranger Things',
#  'The Walking Dead',
#  '13 Reasons Why',
#  'The 100',
#  'Orange Is the New Black',
#  'Riverdale',
#  "Grey's Anatomy",
#  'The Flash',
#  'Arrow',
#  'Money Heist',
#  'The Big Bang Theory',
#  'Black Mirror',
#  'Sherlock',
#  'Vikings',
#  'Pretty Little Liars',
#  'The Vampire Diaries',
#  'American Horror Story',
#  'Breaking Bad',
#  'Lucifer',
#  'Supernatural',
#  'Prison Break',
#  'How to Get Away with Murder',
#  'Teen Wolf',
#  'The Simpsons',
#  'Once Upon a Time',
#  'Narcos',
#  'Daredevil',
#  'Friends',
#  'How I Met Your Mother',
#  'Suits',
#  'Mr. Robot',
#  'The Originals',
#  'Supergirl',
#  'Gossip Girl',
#  'Sense8',
#  'Gotham',
#  'Westworld',
#  'Jessica Jones',
#  'Modern Family',
#  'Rick and Morty',
#  'Shadowhunters',
#  'The End of the F***ing World',
#  'House of Cards',
#  'Dark',
#  'Elite',
#  'Sex Education',
#  'Shameless',
#  'New Girl',
#  'Agents of S.H.I.E.L.D.',
#  'You',
#  'Dexter',
# ...

# %%
year=[]
years=driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
for i in years:
    year.append(i.text)

# %%
year
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017– )',
#  '(2005– )',
#  '(2014–2023)',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011–2019)',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016–2021)',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016–2022)',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2013)',
#  '(2015– )',
#  '(1999– )',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013–2022)',
# ...

# %%
genre=[]
genres=driver.find_elements(By.XPATH,'//span[@class="genre"]')
for i in genres:
    genre.append(i.text)

# %%
genre
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Drama, Mystery, Sci-Fi',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Sci-Fi',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
#  'Drama, Mystery, Sci-Fi',
# ...

# %%
time=[]
times=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in times:
    time.append(i.text)

# %%
time
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
ratings=[]
ratingss=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
for i in ratingss:
    ratings.append(i.text)

# %%
ratings
# Out:
# ['9.2',
#  '8.7',
#  '8.1',
#  '7.5',
#  '7.6',
#  '8.1',
#  '6.6',
#  '7.6',
#  '7.6',
#  '7.5',
#  '8.2',
#  '8.2',
#  '8.8',
#  '9.1',
#  '8.5',
#  '7.4',
#  '7.7',
#  '8',
#  '9.5',
#  '8.1',
#  '8.4',
#  '8.3',
#  '8.1',
#  '7.7',
#  '8.7',
#  '7.7',
#  '8.8',
#  '8.6',
#  '8.9',
#  '8.3',
#  '8.5',
#  '8.6',
#  '8.3',
#  '6.2',
#  '7.5',
#  '8.2',
#  '7.8',
#  '8.5',
#  '7.9',
#  '8.5',
#  '9.1',
#  '6.5',
#  '8.1',
#  '8.7',
#  '8.7',
#  '7.3',
#  '8.4',
#  '8.6',
#  '7.8',
#  '7.5',
#  '7.7',
#  '8.7',
#  '6.8',
#  '8.2',
#  '8',
#  '8.3',
#  '8.8',
#  '8.7',
#  '6.7',
#  '8.3',
#  '8.3',
#  '7.3',
#  '6.8',
#  '8.4',
#  '7.4',
#  '8.1',
#  '7.9',
#  '6.8',
#  '8.7',
#  '8.4',
#  '6.5',
#  '7.9',
#  '8.9',
#  '7.8',
#  '7.6',
#  '8.9',
#  '8.1',
#  '8.5',
#  '8.3',
#  '7.2',
#  '8.7',
#  '8.2',
#  '6.4',
#  '6.3',
#  '8.6',
#  '7.8',
#  '7.3',
#  '7.7',
#  '7.2',
#  '8.5',
#  '6.5',
#  '8.1',
#  '8.7',
#  '9.4',
#  '7.8',
#  '7.4',
#  '7.8',
#  '8.1',
#  '7.1',
#  '8.6']

# %%
votes=[]
votess=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[4]/span[2]')
for i in votess:
    votes.append(i.text)

# %%
votes
# Out:
# ['2,089,164',
#  '1,178,793',
#  '988,385',
#  '292,758',
#  '251,904',
#  '302,839',
#  '145,470',
#  '308,729',
#  '346,268',
#  '431,916',
#  '475,846',
#  '806,877',
#  '545,352',
#  '923,973',
#  '531,485',
#  '167,995',
#  '322,171',
#  '319,509',
#  '1,871,491',
#  '324,250',
#  '445,466',
#  '535,139',
#  '152,219',
#  '148,872',
#  '407,381',
#  '225,384',
#  '421,795',
#  '440,719',
#  '992,313',
#  '682,920',
#  '410,712',
#  '387,570',
#  '136,549',
#  '124,405',
#  '175,397',
#  '154,967',
#  '230,904',
#  '504,823',
#  '215,150',
#  '430,438',
#  '519,025',
#  '64,082',
#  '190,714',
#  '504,535',
#  '384,420',
#  '79,516',
#  '280,308',
#  '243,297',
#  '224,978',
#  '217,635',
#  '240,066',
#  '725,275',
#  '130,366',
#  '339,759',
#  '249,645',
#  '553,318',
#  '545,901',
#  '464,718',
#  '61,270',
#  '111,531',
#  '341,956',
#  '74,395',
#  '105,226',
#  '236,800',
#  '95,696',
#  '95,434',
#  '51,110',
#  '148,964',
#  '369,498',
#  '315,944',
#  '107,024',
# ...

# %%
imdb_tv=pd.DataFrame({'Name':name,'Year span':year,'Genre':genre,'Run time':time,'Ratings':ratings,'Votes':votes})
imdb_tv
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  2,089,164
# ...

# %%
driver.close()

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
# - Url = https://archive.ics.uci.edu/
# - You have to find the following details:
# - A) Dataset name
# - B) Data type
# - C) Task
# - D) Attribute type
# - E) No of instances
# - F) No of attribute
# - G) Year
# - Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
#connecting to driver
driver=webdriver.Chrome(r"D:\softwares\chromedriver_win32\chromedriver.exe")

#maximizing browser window
driver.maximize_window()

# %%
#opening wikipedia.com website
url=' https://archive.ics.uci.edu/'
driver.get(url)
time.sleep(5)

# %%
view_tab=driver.find_element(By.XPATH,'//span[@class="whitetext"]/a/font/b')
view_tab.click()

# %%
url=[]
link=driver.find_elements(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]/a')
for i in link:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://archive.ics.uci.edu/ml/datasets.php']

# %%
name=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        names=driver.find_elements(By.XPATH,'//p[@class="normal"]/b/a')
        for i in names:
            name.append(i.text)
    except NoSuchElementException:
        name.append('-')

# %%
name[:10]
# Out:
# ['Abalone',
#  'Adult',
#  'Annealing',
#  'Anonymous Microsoft Web Data',
#  'Arrhythmia',
#  'Artificial Characters',
#  'Audiology (Original)',
#  'Audiology (Standardized)',
#  'Auto MPG',
#  'Automobile']

# %%
dtype=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        dtypes=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p')
        for i in dtypes:
            dtype.append(i.text)
    except NoSuchElementException:
        dtype.append('-')

# %%
dtype[1:11]
# Out:
# ['Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ']

# %%
task=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        tasks=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p')
        for i in tasks:
            task.append(i.text)
    except NoSuchElementException:
        task.append('-')

# %%
task[1:11]
# Out:
# ['Classification ',
#  'Classification ',
#  'Classification ',
#  'Recommender-Systems ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Regression ',
#  'Regression ']

# %%
att_type=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        att_types=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p')
        for i in att_types:
            att_type.append(i.text)
    except NoSuchElementException:
        att_type.append('-')

# %%
att_type[1:11]
# Out:
# ['Categorical, Integer, Real ',
#  'Categorical, Integer ',
#  'Categorical, Integer, Real ',
#  'Categorical ',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer, Real ',
#  'Categorical ',
#  'Categorical ',
#  'Categorical, Real ',
#  'Categorical, Integer, Real ']

# %%
instances=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        instancess=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p')
        for i in instancess:
            instances.append(i.text)
    except NoSuchElementException:
        instances.append('-')

# %%
instances[1:11]
# Out:
# ['4177 ',
#  '48842 ',
#  '798 ',
#  '37711 ',
#  '452 ',
#  '6000 ',
#  '226 ',
#  '226 ',
#  '398 ',
#  '205 ']

# %%
attribute=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        attributes=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p')
        for i in attributes:
            attribute.append(i.text)
    except NoSuchElementException:
        attribute.append('-')

# %%
attribute[1:11]
# Out:
# ['8 ', '14 ', '38 ', '294 ', '279 ', '7 ', ' ', '69 ', '8 ', '26 ']

# %%
year=[] 
for i in url:
    driver.get(i)
    time.sleep(4)
    try:
        years=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p')
        for i in years:
            year.append(i.text)
    except NoSuchElementException:
        year.append('-')

# %%
year[1:11]
# Out:
# ['1995 ',
#  '1996 ',
#  ' ',
#  '1998 ',
#  '1998 ',
#  '1992 ',
#  '1987 ',
#  '1992 ',
#  '1993 ',
#  '1987 ']

# %%
ML_dataset=pd.DataFrame({'Dataset Name':name[:10],'Data type':dtype[1:11],'Task':task[1:11],'Atttribute type':attribute[1:11],
                        'No. of instances':instances[1:11],'No of attribute':attribute[1:11],'Year':year[1:11]})
ML_dataset
# Out:
#                    Dataset Name      Data type                  Task  \
# 0                       Abalone  Multivariate        Classification
# 1                         Adult  Multivariate        Classification
# 2                     Annealing  Multivariate        Classification
# 3  Anonymous Microsoft Web Data                 Recommender-Systems
# 4                    Arrhythmia  Multivariate        Classification
# 5         Artificial Characters  Multivariate        Classification
# 6          Audiology (Original)  Multivariate        Classification
# 7      Audiology (Standardized)  Multivariate        Classification
# 8                      Auto MPG  Multivariate            Regression
# 9                    Automobile  Multivariate            Regression
#
#   Atttribute type No. of instances No of attribute   Year
# 0              8             4177               8   1995
# 1             14            48842              14   1996
# ...

# %%
driver.close()
